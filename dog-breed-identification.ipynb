# %%
from tensorflow.keras.applications.resnet import preprocess_input 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
traindf = pd.read_csv('../input/dog-breed-identification/labels.csv')

# %%
traindf = train_df.loc[(train_df.breed == 'beagle') | (train_df.breed == 'doberman') | (train_df.breed == 'chihuahua') | (train_df.breed == 'french_bulldog') | (train_df.breed == 'golden_retriever') | (train_df.breed == 'malamute') | (train_df.breed == 'pug') | (train_df.breed == 'saint_bernard') | (train_df.breed == 'scottish_deerhound') | (train_df.breed == 'tibetan_mastiff')].reset_index(drop=True)

# %%
traindf
# Out:
#                                    id               breed
# 0    0021f9ceb3235effd7fcde7f7538ed62    golden_retriever
# 1    0042188c895a2f14ef64a918ed9c7b64  scottish_deerhound
# 2    008b1271ed1addaccf93783b39deab45            doberman
# 3    00a366d4b4a9bbb6c8a63126697b7656    golden_retriever
# 4    0100f55e4f0fe28f2c0465d3fc4b9897    golden_retriever
# ..                                ...                 ...
# 836  fe50bac6c389d137ea01c9cfc7346ca8  scottish_deerhound
# 837  fe624532170510bd80627c0500bafc97     tibetan_mastiff
# 838  feb16cf86c9dac6d476e3c372ba5c279                 pug
# 839  febcab8eb2da444bf83336cffec7eb92    golden_retriever
# 840  ff6f47aa8e181b6efa4d0be7b09b5628    golden_retriever
#
# [841 rows x 2 columns]

# %%
traindf.breed.value_counts()
# Out:
# scottish_deerhound    126
# beagle                105
# pug                    94
# saint_bernard          84
# malamute               81
# doberman               74
# chihuahua              71
# french_bulldog         70
# tibetan_mastiff        69
# golden_retriever       67
# Name: breed, dtype: int64

# %%
train_paths = '../input/dog-breed-identification/train/' + traindf['id'] + '.jpg'

# %%
labels = pd.get_dummies(traindf.breed).values

# %%
column_names = pd.get_dummies(traindf.breed).columns.to_list()

# %%
train_path, valid_path, train_labels, valid_labels = train_test_split(train_paths, labels, test_size=0.3, random_state=42)

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_path, train_labels))
valid_ds = tf.data.Dataset.from_tensor_slices((valid_path, valid_labels))

# %%
def decode_train_data(image_path, label):
    
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.cast(img, tf.float32) / 255.0
    img = tf.image.resize(img,[312,312])
    
    return img, label

# %%
train_ds = train_ds.map(decode_train_data, num_parallel_calls=tf.data.experimental.AUTOTUNE)
valid_ds = valid_ds.map(decode_train_data, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# %%
def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    return img, label

# %%
def configure_for_performance(ds, batch_size = 16):
    
    ds = ds.cache('/kaggle/dump.tfcache')
    ds = ds.map(augment, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    ds = ds.repeat()
    ds = ds.shuffle(buffer_size=25)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return ds

# %%
train_ds_batch = configure_for_performance(train_ds)
valid_ds_batch = valid_ds.batch(32)

# %%
base_model = tf.keras.applications.ResNet50(include_top=False,weights="imagenet")
for layers in base_model.layers:
    layers.trainable=True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
def build_model():
    inputs = tf.keras.layers.Input(shape=(312, 312, 3))
    preprocess = preprocess_input(inputs)
    outputs_resnet = base_model(preprocess)
    global_avg_pooling = tf.keras.layers.GlobalAveragePooling2D()(outputs_resnet)
    dense_1= tf.keras.layers.Dense(512, kernel_regularizer = 'l2')(global_avg_pooling)
    bn_1 = tf.keras.layers.BatchNormalization()(dense_1)
    activation = tf.keras.layers.Activation('relu')(bn_1)
    dropout = tf.keras.layers.Dropout(0.4)(activation)
    dense_2 = tf.keras.layers.Dense(10, activation='softmax')(dropout)
    
    
    model = tf.keras.Model(inputs, dense_2)
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(lr = 3e-4),
        loss='categorical_crossentropy',
        metrics='acc'
    )
    
    return model

# %%
model = build_model()

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 312, 312, 3)]     0
# _________________________________________________________________
# tf.__operators__.getitem (Sl (None, 312, 312, 3)       0
# _________________________________________________________________
# tf.nn.bias_add (TFOpLambda)  (None, 312, 312, 3)       0
# _________________________________________________________________
# resnet50 (Functional)        (None, None, None, 2048)  23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 24,643,978
# Trainable params: 24,589,834
# Non-trainable params: 54,144
# _________________________________________________________________

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    './model.h5', save_best_only=True, monitor='val_loss', mode='min')
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss", patience=4, min_lr=1e-5, mode='min')

# %%
steps_per_epoch = len(train_paths) // 16
epochs = 60
history = model.fit(
                train_ds_batch, 
                validation_data = valid_ds_batch, 
                epochs = epochs,
                callbacks=[checkpoint, lr_reducer],
                steps_per_epoch = steps_per_epoch
)
# Out:
# Epoch 1/60
# 52/52 [==============================] - 23s 266ms/step - loss: 10.7523 - acc: 0.1879 - val_loss: 10.0355 - val_acc: 0.1225
# Epoch 2/60
# 52/52 [==============================] - 11s 203ms/step - loss: 9.6879 - acc: 0.3346 - val_loss: 9.7512 - val_acc: 0.1225
# Epoch 3/60
# 52/52 [==============================] - 10s 199ms/step - loss: 8.8106 - acc: 0.3769 - val_loss: 9.1737 - val_acc: 0.1581
# Epoch 4/60
# 52/52 [==============================] - 10s 196ms/step - loss: 7.6858 - acc: 0.5402 - val_loss: 8.5482 - val_acc: 0.0909
# Epoch 5/60
# 52/52 [==============================] - 10s 196ms/step - loss: 6.7078 - acc: 0.6648 - val_loss: 8.0959 - val_acc: 0.0909
# Epoch 6/60
# 52/52 [==============================] - 10s 196ms/step - loss: 6.0582 - acc: 0.6765 - val_loss: 7.6787 - val_acc: 0.1581
# Epoch 7/60
# 52/52 [==============================] - 10s 195ms/step - loss: 5.1407 - acc: 0.8195 - val_loss: 52.5754 - val_acc: 0.0988
# Epoch 8/60
# 52/52 [==============================] - 10s 197ms/step - loss: 4.6396 - acc: 0.8053 - val_loss: 14.3282 - val_acc: 0.1581
# Epoch 9/60
# 52/52 [==============================] - 10s 199ms/step - loss: 4.0300 - acc: 0.8662 - val_loss: 9.7446 - val_acc: 0.0672
# Epoch 10/60
# 52/52 [==============================] - 10s 193ms/step - loss: 3.5210 - acc: 0.8924 - val_loss: 11.6413 - val_acc: 0.0672
# Epoch 11/60
# 52/52 [==============================] - 10s 195ms/step - loss: 3.1071 - acc: 0.9356 - val_loss: 8.9628 - val_acc: 0.0672
# Epoch 12/60
# 52/52 [==============================] - 10s 197ms/step - loss: 2.9792 - acc: 0.9669 - val_loss: 7.4910 - val_acc: 0.0672
# Epoch 13/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.9156 - acc: 0.9752 - val_loss: 6.2789 - val_acc: 0.1028
# Epoch 14/60
# 52/52 [==============================] - 10s 194ms/step - loss: 2.8352 - acc: 0.9977 - val_loss: 5.8578 - val_acc: 0.1344
# Epoch 15/60
# 52/52 [==============================] - 10s 197ms/step - loss: 2.8010 - acc: 0.9904 - val_loss: 6.3323 - val_acc: 0.1897
# Epoch 16/60
# 52/52 [==============================] - 10s 194ms/step - loss: 2.7456 - acc: 0.9929 - val_loss: 9.1648 - val_acc: 0.0870
# Epoch 17/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.7031 - acc: 0.9880 - val_loss: 8.2575 - val_acc: 0.1383
# Epoch 18/60
# 52/52 [==============================] - 10s 197ms/step - loss: 2.6414 - acc: 0.9955 - val_loss: 6.7168 - val_acc: 0.1502
# Epoch 19/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.6098 - acc: 0.9912 - val_loss: 4.6611 - val_acc: 0.4269
# Epoch 20/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.5922 - acc: 0.9894 - val_loss: 3.3843 - val_acc: 0.7470
# Epoch 21/60
# 52/52 [==============================] - 10s 196ms/step - loss: 2.5619 - acc: 0.9981 - val_loss: 3.6383 - val_acc: 0.6640
# Epoch 22/60
# 52/52 [==============================] - 10s 194ms/step - loss: 2.5551 - acc: 0.9969 - val_loss: 4.7829 - val_acc: 0.3676
# Epoch 23/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.5268 - acc: 0.9977 - val_loss: 7.0223 - val_acc: 0.1186
# Epoch 24/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.5109 - acc: 0.9956 - val_loss: 4.1896 - val_acc: 0.4743
# Epoch 25/60
# 52/52 [==============================] - 10s 194ms/step - loss: 2.4812 - acc: 1.0000 - val_loss: 3.6109 - val_acc: 0.6522
# Epoch 26/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.4655 - acc: 0.9990 - val_loss: 3.4542 - val_acc: 0.7036
# Epoch 27/60
# 52/52 [==============================] - 10s 199ms/step - loss: 2.4562 - acc: 0.9918 - val_loss: 3.8614 - val_acc: 0.5455
# Epoch 28/60
# 52/52 [==============================] - 10s 196ms/step - loss: 2.4310 - acc: 0.9936 - val_loss: 3.7005 - val_acc: 0.6285
# Epoch 29/60
# 52/52 [==============================] - 10s 193ms/step - loss: 2.4183 - acc: 0.9907 - val_loss: 3.6232 - val_acc: 0.6126
# Epoch 30/60
# 52/52 [==============================] - 10s 197ms/step - loss: 2.3839 - acc: 0.9995 - val_loss: 3.6397 - val_acc: 0.6443
# Epoch 31/60
# 52/52 [==============================] - 10s 194ms/step - loss: 2.3652 - acc: 0.9970 - val_loss: 3.9221 - val_acc: 0.5217
# Epoch 32/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.3325 - acc: 1.0000 - val_loss: 4.6498 - val_acc: 0.3676
# Epoch 33/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.3126 - acc: 1.0000 - val_loss: 5.4718 - val_acc: 0.2490
# Epoch 34/60
# 52/52 [==============================] - 10s 193ms/step - loss: 2.2892 - acc: 0.9993 - val_loss: 4.2751 - val_acc: 0.4348
# Epoch 35/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.2733 - acc: 0.9964 - val_loss: 3.1863 - val_acc: 0.7075
# Epoch 36/60
# 52/52 [==============================] - 10s 197ms/step - loss: 2.2599 - acc: 0.9937 - val_loss: 2.9601 - val_acc: 0.7589
# Epoch 37/60
# 52/52 [==============================] - 10s 196ms/step - loss: 2.2223 - acc: 0.9978 - val_loss: 2.9798 - val_acc: 0.7312
# Epoch 38/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.1991 - acc: 0.9973 - val_loss: 3.1536 - val_acc: 0.6759
# Epoch 39/60
# 52/52 [==============================] - 10s 200ms/step - loss: 2.1697 - acc: 0.9995 - val_loss: 4.7882 - val_acc: 0.3636
# Epoch 40/60
# 52/52 [==============================] - 10s 194ms/step - loss: 2.1438 - acc: 0.9988 - val_loss: 2.9167 - val_acc: 0.7549
# Epoch 41/60
# 52/52 [==============================] - 10s 195ms/step - loss: 2.1200 - acc: 0.9985 - val_loss: 4.2909 - val_acc: 0.4466
# Epoch 42/60
# 52/52 [==============================] - 11s 205ms/step - loss: 2.0945 - acc: 0.9998 - val_loss: 2.8744 - val_acc: 0.7549
# Epoch 43/60
# 52/52 [==============================] - 10s 198ms/step - loss: 2.0718 - acc: 0.9995 - val_loss: 4.4701 - val_acc: 0.3794
# Epoch 44/60
# 52/52 [==============================] - 10s 199ms/step - loss: 2.0430 - acc: 0.9958 - val_loss: 2.8831 - val_acc: 0.7549
# Epoch 45/60
# 52/52 [==============================] - 10s 196ms/step - loss: 2.0102 - acc: 1.0000 - val_loss: 3.2209 - val_acc: 0.6364
# Epoch 46/60
# 52/52 [==============================] - 10s 200ms/step - loss: 1.9891 - acc: 0.9981 - val_loss: 5.6149 - val_acc: 0.1976
# Epoch 47/60
# 52/52 [==============================] - 10s 196ms/step - loss: 1.9610 - acc: 1.0000 - val_loss: 3.4137 - val_acc: 0.6008
# Epoch 48/60
# 52/52 [==============================] - 10s 195ms/step - loss: 1.9351 - acc: 1.0000 - val_loss: 3.6676 - val_acc: 0.5020
# Epoch 49/60
# 52/52 [==============================] - 10s 195ms/step - loss: 1.9068 - acc: 0.9980 - val_loss: 2.9249 - val_acc: 0.6957
# Epoch 50/60
# 52/52 [==============================] - 10s 195ms/step - loss: 1.8749 - acc: 1.0000 - val_loss: 3.4951 - val_acc: 0.5494
# Epoch 51/60
# 52/52 [==============================] - 10s 196ms/step - loss: 1.8514 - acc: 0.9983 - val_loss: 5.1503 - val_acc: 0.2806
# Epoch 52/60
# 52/52 [==============================] - 10s 198ms/step - loss: 1.8207 - acc: 1.0000 - val_loss: 3.1702 - val_acc: 0.6640
# Epoch 53/60
# 52/52 [==============================] - 10s 196ms/step - loss: 1.7928 - acc: 1.0000 - val_loss: 2.7179 - val_acc: 0.7312
# Epoch 54/60
# 52/52 [==============================] - 10s 194ms/step - loss: 1.7633 - acc: 1.0000 - val_loss: 2.5891 - val_acc: 0.7470
# Epoch 55/60
# 52/52 [==============================] - 10s 198ms/step - loss: 1.7406 - acc: 0.9986 - val_loss: 5.2463 - val_acc: 0.2055
# Epoch 56/60
# 52/52 [==============================] - 10s 195ms/step - loss: 1.7097 - acc: 0.9984 - val_loss: 4.6060 - val_acc: 0.3202
# Epoch 57/60
# 52/52 [==============================] - 10s 195ms/step - loss: 1.6792 - acc: 1.0000 - val_loss: 3.4450 - val_acc: 0.5415
# Epoch 58/60
# 52/52 [==============================] - 10s 197ms/step - loss: 1.6516 - acc: 0.9975 - val_loss: 5.7677 - val_acc: 0.1621
# Epoch 59/60
# 52/52 [==============================] - 10s 194ms/step - loss: 1.6201 - acc: 0.9999 - val_loss: 4.9404 - val_acc: 0.2846
# Epoch 60/60
# 52/52 [==============================] - 10s 194ms/step - loss: 1.5923 - acc: 0.9976 - val_loss: 4.7775 - val_acc: 0.1937
